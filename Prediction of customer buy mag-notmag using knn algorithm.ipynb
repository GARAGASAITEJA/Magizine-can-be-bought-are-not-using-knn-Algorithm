# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'C:\Users\VAIO\Desktop\PYQT5\ml1\LogisticRegression\Magzine\Magzine.ui'
#
# Created by: PyQt5 UI code generator 5.15.4
#
# WARNING: Any manual changes made to this file will be lost when pyuic5 is
# run again.  Do not edit this file unless you know what you are doing.


from PyQt5 import QtCore, QtGui, QtWidgets


class Ui_Form(object):
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(587, 517)
        Form.setStyleSheet("font: 10pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 0, 255)")
        self.label = QtWidgets.QLabel(Form)
        self.label.setGeometry(QtCore.QRect(100, 50, 47, 13))
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(Form)
        self.label_2.setGeometry(QtCore.QRect(100, 80, 47, 13))
        self.label_2.setObjectName("label_2")
        self.label_3 = QtWidgets.QLabel(Form)
        self.label_3.setGeometry(QtCore.QRect(86, 110, 61, 20))
        self.label_3.setObjectName("label_3")
        self.label_4 = QtWidgets.QLabel(Form)
        self.label_4.setGeometry(QtCore.QRect(86, 150, 61, 20))
        self.label_4.setObjectName("label_4")
        self.label_5 = QtWidgets.QLabel(Form)
        self.label_5.setGeometry(QtCore.QRect(86, 200, 61, 20))
        self.label_5.setObjectName("label_5")
        self.label_6 = QtWidgets.QLabel(Form)
        self.label_6.setGeometry(QtCore.QRect(336, 40, 81, 20))
        self.label_6.setObjectName("label_6")
        self.label_7 = QtWidgets.QLabel(Form)
        self.label_7.setGeometry(QtCore.QRect(356, 80, 61, 20))
        self.label_7.setObjectName("label_7")
        self.label_8 = QtWidgets.QLabel(Form)
        self.label_8.setGeometry(QtCore.QRect(370, 120, 47, 13))
        self.label_8.setObjectName("label_8")
        self.label_9 = QtWidgets.QLabel(Form)
        self.label_9.setGeometry(QtCore.QRect(370, 160, 47, 13))
        self.label_9.setObjectName("label_9")
        self.label_10 = QtWidgets.QLabel(Form)
        self.label_10.setGeometry(QtCore.QRect(370, 200, 47, 13))
        self.label_10.setObjectName("label_10")
        self.label_11 = QtWidgets.QLabel(Form)
        self.label_11.setGeometry(QtCore.QRect(66, 240, 91, 20))
        self.label_11.setObjectName("label_11")
        self.label_12 = QtWidgets.QLabel(Form)
        self.label_12.setGeometry(QtCore.QRect(370, 240, 47, 13))
        self.label_12.setObjectName("label_12")
        self.label_13 = QtWidgets.QLabel(Form)
        self.label_13.setGeometry(QtCore.QRect(86, 280, 61, 20))
        self.label_13.setObjectName("label_13")
        self.label_14 = QtWidgets.QLabel(Form)
        self.label_14.setGeometry(QtCore.QRect(356, 280, 61, 20))
        self.label_14.setObjectName("label_14")
        self.label_15 = QtWidgets.QLabel(Form)
        self.label_15.setGeometry(QtCore.QRect(66, 320, 81, 20))
        self.label_15.setObjectName("label_15")
        self.label_16 = QtWidgets.QLabel(Form)
        self.label_16.setGeometry(QtCore.QRect(346, 320, 71, 20))
        self.label_16.setObjectName("label_16")
        self.label_17 = QtWidgets.QLabel(Form)
        self.label_17.setGeometry(QtCore.QRect(76, 360, 71, 20))
        self.label_17.setObjectName("label_17")
        self.lineEdit = QtWidgets.QLineEdit(Form)
        self.lineEdit.setGeometry(QtCore.QRect(170, 50, 113, 20))
        self.lineEdit.setObjectName("lineEdit")
        self.lineEdit_2 = QtWidgets.QLineEdit(Form)
        self.lineEdit_2.setGeometry(QtCore.QRect(170, 80, 113, 20))
        self.lineEdit_2.setObjectName("lineEdit_2")
        self.lineEdit_3 = QtWidgets.QLineEdit(Form)
        self.lineEdit_3.setGeometry(QtCore.QRect(170, 110, 113, 20))
        self.lineEdit_3.setObjectName("lineEdit_3")
        self.lineEdit_4 = QtWidgets.QLineEdit(Form)
        self.lineEdit_4.setGeometry(QtCore.QRect(170, 150, 113, 20))
        self.lineEdit_4.setObjectName("lineEdit_4")
        self.lineEdit_5 = QtWidgets.QLineEdit(Form)
        self.lineEdit_5.setGeometry(QtCore.QRect(170, 200, 113, 20))
        self.lineEdit_5.setObjectName("lineEdit_5")
        self.lineEdit_6 = QtWidgets.QLineEdit(Form)
        self.lineEdit_6.setGeometry(QtCore.QRect(170, 240, 113, 20))
        self.lineEdit_6.setObjectName("lineEdit_6")
        self.lineEdit_7 = QtWidgets.QLineEdit(Form)
        self.lineEdit_7.setGeometry(QtCore.QRect(170, 280, 113, 20))
        self.lineEdit_7.setObjectName("lineEdit_7")
        self.lineEdit_8 = QtWidgets.QLineEdit(Form)
        self.lineEdit_8.setGeometry(QtCore.QRect(170, 320, 113, 20))
        self.lineEdit_8.setObjectName("lineEdit_8")
        self.lineEdit_9 = QtWidgets.QLineEdit(Form)
        self.lineEdit_9.setGeometry(QtCore.QRect(170, 360, 113, 20))
        self.lineEdit_9.setObjectName("lineEdit_9")
        self.lineEdit_10 = QtWidgets.QLineEdit(Form)
        self.lineEdit_10.setGeometry(QtCore.QRect(430, 40, 113, 20))
        self.lineEdit_10.setObjectName("lineEdit_10")
        self.lineEdit_11 = QtWidgets.QLineEdit(Form)
        self.lineEdit_11.setGeometry(QtCore.QRect(430, 80, 113, 20))
        self.lineEdit_11.setObjectName("lineEdit_11")
        self.lineEdit_12 = QtWidgets.QLineEdit(Form)
        self.lineEdit_12.setGeometry(QtCore.QRect(430, 120, 113, 20))
        self.lineEdit_12.setObjectName("lineEdit_12")
        self.lineEdit_13 = QtWidgets.QLineEdit(Form)
        self.lineEdit_13.setGeometry(QtCore.QRect(430, 160, 113, 20))
        self.lineEdit_13.setObjectName("lineEdit_13")
        self.lineEdit_14 = QtWidgets.QLineEdit(Form)
        self.lineEdit_14.setGeometry(QtCore.QRect(430, 200, 113, 20))
        self.lineEdit_14.setObjectName("lineEdit_14")
        self.lineEdit_15 = QtWidgets.QLineEdit(Form)
        self.lineEdit_15.setGeometry(QtCore.QRect(430, 240, 113, 20))
        self.lineEdit_15.setObjectName("lineEdit_15")
        self.lineEdit_16 = QtWidgets.QLineEdit(Form)
        self.lineEdit_16.setGeometry(QtCore.QRect(430, 280, 113, 20))
        self.lineEdit_16.setObjectName("lineEdit_16")
        self.lineEdit_17 = QtWidgets.QLineEdit(Form)
        self.lineEdit_17.setGeometry(QtCore.QRect(430, 320, 113, 20))
        self.lineEdit_17.setObjectName("lineEdit_17")
        self.pushButton = QtWidgets.QPushButton(Form)
        self.pushButton.setGeometry(QtCore.QRect(224, 420, 101, 23))
        self.pushButton.setObjectName("pushButton")
        self.label_19 = QtWidgets.QLabel(Form)
        self.label_19.setGeometry(QtCore.QRect(236, 470, 71, 20))
        self.label_19.setObjectName("label_19")

        self.retranslateUi(Form)
        QtCore.QMetaObject.connectSlotsByName(Form)
        
        self.pushButton.clicked.connect(self.predictmagizine)

    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "Form"))
        self.label.setText(_translate("Form", "Obs.No:"))
        self.label_2.setText(_translate("Form", " Income:"))
        self.label_3.setText(_translate("Form", " Is Female:"))
        self.label_4.setText(_translate("Form", "Is Married:"))
        self.label_5.setText(_translate("Form", "Has College:"))
        self.label_6.setText(_translate("Form", " Dual Income:"))
        self.label_7.setText(_translate("Form", "Minors:"))
        self.label_8.setText(_translate("Form", " Own:"))
        self.label_9.setText(_translate("Form", "House:"))
        self.label_10.setText(_translate("Form", "White:"))
        self.label_11.setText(_translate("Form", "Is Professional:\'"))
        self.label_12.setText(_translate("Form", "English:"))
        self.label_13.setText(_translate("Form", "Is Retired:"))
        self.label_14.setText(_translate("Form", "Prev Child:"))
        self.label_15.setText(_translate("Form", " Umemployed:"))
        self.label_16.setText(_translate("Form", "Prev Parent"))
        self.label_17.setText(_translate("Form", " Residence:"))
        self.pushButton.setText(_translate("Form", "Mag/Not Mag"))
        self.label_19.setText(_translate("Form", " Output"))
    
    def predictmagizine(self):
        import pandas as pd
        import sklearn

        from sklearn.model_selection import train_test_split
        path="C:\\Users\\VAIO\\Desktop\\PYQT5\\ml1\\LogisticRegression\\Magzine\\Kid.csv"
        data=pd.read_csv(path)
        inputs=data.drop(['Buy'],'columns')
        print(inputs)
        output=data.drop(['Obs No.','Income','Is Female','Is Married','Has College','Is Professional','Is Retired',
                          'Unemployed','Residence Length','Dual Income','Minors','Own','House','White',
                        'English','Prev Child Mag','Prev Parent Mag'],'columns')
      
        print(output)
        x_train,x_test,y_train,y_test=train_test_split(inputs,output,train_size=0.8)
        
        from sklearn.neighbors import KNeighborsClassifier
        model=KNeighborsClassifier(n_neighbors=25)
        model.fit(x_train,y_train)
        
        strObsno=int(self.lineEdit.text())
        strIncome=int(self.lineEdit_2.text())
        strIsFemale=int(self.lineEdit_3.text())
        strIsMarried=int(self.lineEdit_4.text())
        strHasCollege=int(self.lineEdit_5.text())
        strIsProfessional=int(self.lineEdit_6.text())
        strIsRetired=int(self.lineEdit_7.text())
        strUnemployed=int(self.lineEdit_8.text())
        strResidenceLength=int(self.lineEdit_9.text())
        strDualIncome=int(self.lineEdit_10.text())
        strMinors=int(self.lineEdit_11.text())
        strOwn=int(self.lineEdit_12.text())
        strHouse=int(self.lineEdit_13.text())
        strWhite=int(self.lineEdit_14.text())
        strEnglish=int(self.lineEdit_15.text())
        strPrevChildMag=int(self.lineEdit_16.text())
        strPrevParentMag=int(self.lineEdit_17.text())
                
        strresult=model.predict([[strObsno,strIncome,strIsFemale,strIsMarried,strHasCollege,strIsProfessional
                                 ,strIsRetired,strUnemployed,strResidenceLength,strDualIncome,strMinors,
                                  strOwn,strHouse,strWhite,strEnglish,strPrevChildMag,strPrevParentMag]])
        self.label_19.setText((str(strresult)))
         

if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Form = QtWidgets.QWidget()
    ui = Ui_Form()
    ui.setupUi(Form)
    Form.show()
    sys.exit(app.exec_())
# Out:
#      Obs No.  Income  Is Female  Is Married  Has College  Is Professional  \
# 0          1   24000          1           0            1                1
# 1          2   75000          1           1            1                1
# 2          3   46000          1           1            0                0
# 3          4   70000          0           1            0                1
# 4          5   43000          1           0            0                0
# ..       ...     ...        ...         ...          ...              ...
# 668      669   27000          1           0            0                0
# 669      670    3000          1           0            0                0
# 670      671   75000          1           1            0                1
# 671      672   51000          1           1            0                1
# 672      673   11000          0           1            0                0
#
#      Is Retired  Unemployed  Residence Length  Dual Income  Minors  Own  \
# ...
